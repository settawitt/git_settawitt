# %% [markdown]
# <a href="https://colab.research.google.com/github/settawitt/git_settawitt/blob/master/E_2023_Oct_Python_Pandas_Null_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create DataFrame with None/Null to work with examples
import pandas as pd
import numpy as np
technologies   = {
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas",None,"Spark","Python"],
    'Fee' :[22000,25000,23000,24000,np.nan,25000,25000,22000],
    'Duration':['30day','50days','55days','40days','60days','35day','','50days'],
    'Discount':[1000,2300,1000,1200,2500,1300,1400,1600]
          }
row_labels=['r0','r1','r2','r3','r4','r5','r6','r7']
df = pd.DataFrame(technologies, index=row_labels)
print(df)
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %%
df
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Fee'].plot(kind='hist', bins=20, title='Fee')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# plt.tight_layout()
# from matplotlib import pyplot as plt
# df['Discount'].plot(kind='hist', bins=20, title='Discount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# plt.tight_layout()
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Courses').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Duration').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# plt.figure(figsize=(6, 6))
# df.plot(kind='scatter', x='Fee', y='Discount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# plt.tight_layout()
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Fee'].plot(kind='line', figsize=(8, 4), title='Fee')
# plt.gca().spines[['top', 'right']].set_visible(False)
# plt.tight_layout()
# from matplotlib import pyplot as plt
# df['Discount'].plot(kind='line', figsize=(8, 4), title='Discount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# plt.tight_layout()
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Duration'].value_counts()
#     for x_label, grp in df.groupby('Courses')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Courses')
# plt.ylabel('Duration')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Courses'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Fee', y='Courses', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Duration'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Fee', y='Duration', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Courses'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Discount', y='Courses', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Duration'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Discount', y='Duration', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.values ## convert to array()
# Out:
# array([['Spark', 22000.0, '30day', 1000],
#        ['PySpark', 25000.0, '50days', 2300],
#        ['Hadoop', 23000.0, '55days', 1000],
#        ['Python', 24000.0, '40days', 1200],
#        ['Pandas', nan, '60days', 2500],
#        [None, 25000.0, '35day', 1300],
#        ['Spark', 25000.0, '', 1400],
#        ['Python', 22000.0, '50days', 1600]], dtype=object)

# %%
# 1. Null Summary

df.isnull().values.any() #ให้ค่า True เมื่อมี Null ใน Dataframe
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Courses     1
# Fee         1
# Duration    0
# Discount    0
# dtype: int64

# %%
type(df.isnull().sum())
# Out:
# pandas.core.series.Series

# %%
# นำผลการทำ Null Summary มาสร้างเป็น DataFrame

pd.DataFrame(df.isnull().sum())
# Out:
#           0
# Courses   1
# Fee       1
# Duration  0
# Discount  0

# %%
pd.DataFrame(df.isnull().sum())[0]['Fee']

## ความรู้เดิม Subdata with column LABEL index and row LABEL index
# Out:
# 1

# %%
df.columns

## ความรู้เดิม แสดง Column Index Label
# Out:
# Index(['Courses', 'Fee', 'Duration', 'Discount'], dtype='object')

# %%
df.isnull().sum().values
# Out:
# array([1, 1, 0, 0])

# %%
pd.DataFrame({'col_name':df.columns,'num_null':df.isnull().sum().values})
# Out:
#    col_name  num_null
# 0   Courses         1
# 1       Fee         1
# 2  Duration         0
# 3  Discount         0

# %%
# 2. Locate Null

# %%
df[df['Courses'].isnull()] # ตัดมาเฉพาะ Row ที่ Column 'Courses' เป็น Null

## Subdata with Boolean index
# Out:
#    Courses      Fee Duration  Discount
# r5    None  25000.0    35day      1300

# %%
df.isnull().any()
# Out:
# Courses      True
# Fee          True
# Duration    False
# Discount    False
# dtype: bool

# %%
# ตัดมาเฉพาะ Column ที่มี Element เป็น Null
# สังเกตว่า ผลลัพธ์จะมีครบทุก Row แต่อาจมีไม่ครบทุก Column
# เฉพาะ Column ที่มี Element เป็น Null เท่านั้น

df[df.columns[df.isnull().any()]]
# Out:
#     Courses      Fee
# r0    Spark  22000.0
# r1  PySpark  25000.0
# r2   Hadoop  23000.0
# r3   Python  24000.0
# r4   Pandas      NaN
# r5     None  25000.0
# r6    Spark  25000.0
# r7   Python  22000.0

# %%
df.apply(lambda x: x == "").any()
# Out:
# Courses     False
# Fee         False
# Duration     True
# Discount    False
# dtype: bool

# %%
# ตัดมาเฉพาะ Column ที่มี Element เป็น empty value
# สังเกตว่า ผลลัพธ์จะมีครบทุก Row แต่อาจมีไม่ครบทุก Column
# เฉพาะ Column ที่มี Element เป็น empty value เท่านั้น

df[df.columns[df.apply(lambda x: x == "").any()]]
# Out:
#    Duration
# r0    30day
# r1   50days
# r2   55days
# r3   40days
# r4   60days
# r5    35day
# r6
# r7   50days

# %%
df.isnull().any(axis=1)
# Out:
# r0    False
# r1    False
# r2    False
# r3    False
# r4     True
# r5     True
# r6    False
# r7    False
# dtype: bool

# %%
# ตัดมาเฉพาะ Row ที่มี Element เป็น Null
# สังเกตว่า ผลลัพธ์จะมีครบทุก Column แต่อาจมีไม่ครบทุก Row
# เฉพาะ Row ที่มี Element เป็น Null เท่านั้น


df[df.isnull().any(axis=1)]
# Out:
#    Courses      Fee Duration  Discount
# r4  Pandas      NaN   60days      2500
# r5    None  25000.0    35day      1300

# %%
# ตัดมาเฉพาะ Row ที่มี Element เป็น empty value
# สังเกตว่า ผลลัพธ์จะมีครบทุก Column แต่อาจมีไม่ครบทุก Row
# เฉพาะ Row ที่มี Element เป็น empty value เท่านั้น


df[df.apply(lambda x:x == "").any(axis=1)]
# Out:
#    Courses      Fee Duration  Discount
# r6   Spark  25000.0               1400

# %%
## ตัดมาเฉพาะ Row หรือ Column ที่มี Null เท่านั้น

df[df.columns[df.isnull().any()]][df.isnull().any(axis=1)]
# Out:
#    Courses      Fee
# r4  Pandas      NaN
# r5    None  25000.0

# %%
df[df.isnull().any(axis=1)][df.columns[df.isnull().any()]]
# Out:
#    Courses      Fee
# r4  Pandas      NaN
# r5    None  25000.0
