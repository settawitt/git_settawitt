# %% [markdown]
# <a href="https://colab.research.google.com/github/settawitt/git_settawitt/blob/master/Homework_Python_Pandas_CoeffVariation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! wget https://storage.googleapis.com/1sep/2008.csv
# Out:
# --2023-10-21 15:36:19--  https://storage.googleapis.com/1sep/2008.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.141.207, 173.194.210.207, 173.194.211.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.141.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689413344 (657M) [text/csv]
# Saving to: ‘2008.csv’
#
# 2008.csv            100%[===================>] 657.48M  34.6MB/s    in 6.6s
#
# 2023-10-21 15:36:25 (99.8 MB/s) - ‘2008.csv’ saved [689413344/689413344]

# %%
! wc -l 2008.csv
# Out:
# 7009729 2008.csv

# %%
f = "2008.csv"
num_lines = sum(1 for l in open(f))
size = int(num_lines / 100)
import random
skip_idx = random.sample(range(1, num_lines), num_lines - size)
raw_pd = pd.read_csv(f, skiprows=skip_idx)

# %%
#raw_pd = pd.read_csv("2008.csv")

# %%
raw_pd.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1029.0        1020   1021.0
# 1  2008      1           3          4   2039.0        1930    155.0
# 2  2008      1           3          4   1734.0        1655   1857.0
# 3  2008      1           3          4    617.0         615    743.0
# 4  2008      1           3          4   1631.0        1630   1749.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1010            WN       2272  ...    6.0      9.0          0
# 1          55            WN       3940  ...    5.0     14.0          0
# 2        1820            WN       3844  ...    5.0     12.0          0
# 3         735            WN        424  ...    6.0     21.0          0
# 4        1750            WN       1006  ...    5.0     11.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           0.0          0.0     22.0
# 2               NaN         0           9.0          0.0      0.0
# 3               NaN         0           NaN          NaN      NaN
# 4               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            0.0               38.0
# 2            0.0               28.0
# 3            NaN                NaN
# 4            NaN                NaN
#
# [5 rows x 29 columns]

# %%
raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70096 entries, 0 to 70095
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               70096 non-null  int64
#  1   Month              70096 non-null  int64
#  2   DayofMonth         70096 non-null  int64
#  3   DayOfWeek          70096 non-null  int64
#  4   DepTime            68772 non-null  float64
#  5   CRSDepTime         70096 non-null  int64
#  6   ArrTime            68601 non-null  float64
#  7   CRSArrTime         70096 non-null  int64
#  8   UniqueCarrier      70096 non-null  object
#  9   FlightNum          70096 non-null  int64
#  10  TailNum            69279 non-null  object
#  11  ActualElapsedTime  68574 non-null  float64
#  12  CRSElapsedTime     70086 non-null  float64
#  13  AirTime            68574 non-null  float64
#  14  ArrDelay           68574 non-null  float64
#  15  DepDelay           68772 non-null  float64
#  16  Origin             70096 non-null  object
#  17  Dest               70096 non-null  object
#  18  Distance           70096 non-null  int64
#  19  TaxiIn             68601 non-null  float64
#  20  TaxiOut            68763 non-null  float64
#  21  Cancelled          70096 non-null  int64
#  22  CancellationCode   1337 non-null   object
#  23  Diverted           70096 non-null  int64
#  24  CarrierDelay       15218 non-null  float64
#  25  WeatherDelay       15218 non-null  float64
#  26  NASDelay           15218 non-null  float64
#  27  SecurityDelay      15218 non-null  float64
#  28  LateAircraftDelay  15218 non-null  float64
# dtypes: float64(14), int64(10), object(5)
# memory usage: 15.5+ MB

# %%
raw_pd.describe().transpose()
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               70096.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              70096.0     6.365028     3.404681     1.0     3.0     6.0
# DayofMonth         70096.0    15.730983     8.784450     1.0     8.0    16.0
# DayOfWeek          70096.0     3.913676     1.991181     1.0     2.0     4.0
# DepTime            68772.0  1333.610176   478.325981     1.0   928.0  1326.0
# CRSDepTime         70096.0  1326.465761   464.033503     1.0   925.0  1320.0
# ArrTime            68601.0  1480.920759   505.732493     1.0  1106.0  1515.0
# CRSArrTime         70096.0  1495.160751   483.182418     1.0  1115.0  1520.0
# FlightNum          70096.0  2210.528247  1953.720486     1.0   617.0  1563.0
# ActualElapsedTime  68574.0   127.802330    70.096011    16.0    77.0   110.0
# CRSElapsedTime     70086.0   129.373256    69.414444    20.0    80.0   111.0
# AirTime            68574.0   104.466955    67.389816     7.0    56.0    86.0
# ArrDelay           68574.0     8.137516    38.690600   -62.0   -10.0    -2.0
# DepDelay           68772.0     9.953135    35.518667   -35.0    -4.0    -1.0
# Distance           70096.0   730.125656   562.303571    31.0   328.0   585.0
# TaxiIn             68601.0     6.869565     4.962246     1.0     4.0     6.0
# TaxiOut            68763.0    16.476172    11.337648     0.0    10.0    14.0
# Cancelled          70096.0     0.019074     0.136786     0.0     0.0     0.0
# Diverted           70096.0     0.002639     0.051306     0.0     0.0     0.0
# CarrierDelay       15218.0    15.821067    40.992877     0.0     0.0     0.0
# WeatherDelay       15218.0     2.769024    19.321927     0.0     0.0     0.0
# NASDelay           15218.0    17.346432    32.224729     0.0     0.0     6.0
# SecurityDelay      15218.0     0.056249     1.307488     0.0     0.0     0.0
# LateAircraftDelay  15218.0    20.906689    39.195189     0.0     0.0     0.0
#
#                       75%     max
# Year               2008.0  2008.0
# Month                 9.0    12.0
# DayofMonth           23.0    31.0
# DayOfWeek             6.0     7.0
# DepTime            1726.0  2400.0
# CRSDepTime         1715.0  2359.0
# ArrTime            1907.0  2400.0
# CRSArrTime         1905.0  2400.0
# FlightNum          3493.0  7829.0
# ActualElapsedTime   157.0   662.0
# CRSElapsedTime      159.0   660.0
# AirTime             132.0   639.0
# ArrDelay             12.0  1129.0
# DepDelay              8.0  1090.0
# Distance            956.0  4962.0
# TaxiIn                8.0   130.0
# TaxiOut              19.0   272.0
# Cancelled             0.0     1.0
# Diverted              0.0     1.0
# CarrierDelay         16.0  1090.0
# WeatherDelay          0.0   907.0
# NASDelay             21.0   470.0
# SecurityDelay         0.0    70.0
# LateAircraftDelay    26.0   532.0

# %%
describe_pd = pd.DataFrame(raw_pd.describe().transpose())

# %%
describe_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Year to LateAircraftDelay
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   24 non-null     float64
#  1   mean    24 non-null     float64
#  2   std     24 non-null     float64
#  3   min     24 non-null     float64
#  4   25%     24 non-null     float64
#  5   50%     24 non-null     float64
#  6   75%     24 non-null     float64
#  7   max     24 non-null     float64
# dtypes: float64(8)
# memory usage: 2.2+ KB
