# %% [markdown]
# <a href="https://colab.research.google.com/github/settawitt/git_settawitt/blob/master/Homework_Python_Pandas_CoeffVariation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
 ! wget https://storage.googleapis.com/1sep/2008.csv
# Out:
# --2023-10-27 05:30:25--  https://storage.googleapis.com/1sep/2008.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.196.207, 74.125.134.207, 74.125.139.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.196.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689413344 (657M) [text/csv]
# Saving to: ‘2008.csv’
#
# 2008.csv            100%[===================>] 657.48M   237MB/s    in 2.8s
#
# 2023-10-27 05:30:28 (237 MB/s) - ‘2008.csv’ saved [689413344/689413344]

# %%
 ! wc -l 2008.csv
# Out:
# 7009729 2008.csv

# %%
f = "2008.csv"
num_lines = sum(1 for l in open(f))
size = int(num_lines / 100)
import random
skip_idx = random.sample(range(1, num_lines), num_lines - size)
raw_pd = pd.read_csv(f, skiprows=skip_idx)

# %%
#raw_pd = pd.read_csv("2008.csv")

# %%
raw_pd.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1433.0        1440   1623.0
# 1  2008      1           3          4   1147.0        1100   1541.0
# 2  2008      1           3          4   1925.0        1825   2024.0
# 3  2008      1           3          4   1516.0        1500   1614.0
# 4  2008      1           3          4   1251.0        1235   1415.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1625            WN       1331  ...    2.0     13.0          0
# 1        1500            WN       2382  ...    4.0     20.0          0
# 2        1930            WN       2359  ...    3.0      7.0          0
# 3        1605            WN         41  ...    3.0      6.0          0
# 4        1405            WN         33  ...    4.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70096 entries, 0 to 70095
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               70096 non-null  int64
#  1   Month              70096 non-null  int64
#  2   DayofMonth         70096 non-null  int64
#  3   DayOfWeek          70096 non-null  int64
#  4   DepTime            68673 non-null  float64
#  5   CRSDepTime         70096 non-null  int64
#  6   ArrTime            68530 non-null  float64
#  7   CRSArrTime         70096 non-null  int64
#  8   UniqueCarrier      70096 non-null  object
#  9   FlightNum          70096 non-null  int64
#  10  TailNum            69200 non-null  object
#  11  ActualElapsedTime  68503 non-null  float64
#  12  CRSElapsedTime     70085 non-null  float64
#  13  AirTime            68503 non-null  float64
#  14  ArrDelay           68503 non-null  float64
#  15  DepDelay           68673 non-null  float64
# ...

# %%
desc = raw_pd.describe().transpose()
desc
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               70096.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              70096.0     6.366612     3.406746     1.0     3.0     6.0
# DayofMonth         70096.0    15.730270     8.816908     1.0     8.0    16.0
# DayOfWeek          70096.0     3.919567     1.987867     1.0     2.0     4.0
# DepTime            68673.0  1337.116348   479.604373     1.0   930.0  1328.0
# CRSDepTime         70096.0  1330.474278   465.311936     1.0   930.0  1324.0
# ArrTime            68530.0  1482.563884   507.295911     1.0  1107.0  1513.5
# CRSArrTime         70096.0  1496.732567   484.290227     1.0  1115.0  1520.0
# FlightNum          70096.0  2219.443121  1958.201811     1.0   620.0  1568.0
# ActualElapsedTime  68503.0   127.095470    69.766755    16.0    76.0   110.0
# CRSElapsedTime     70085.0   128.631476    68.951110     1.0    80.0   111.0
# ...

# %%
describe_pd = pd.DataFrame(raw_pd.describe().transpose())

# %%
describe_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Year to LateAircraftDelay
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   24 non-null     float64
#  1   mean    24 non-null     float64
#  2   std     24 non-null     float64
#  3   min     24 non-null     float64
#  4   25%     24 non-null     float64
#  5   50%     24 non-null     float64
#  6   75%     24 non-null     float64
#  7   max     24 non-null     float64
# dtypes: float64(8)
# memory usage: 2.2+ KB

# %%
# std
data = pd.DataFrame(raw_pd)

# %%
print("Year std = ",(data['Year']).std())
print("Month std = ",(data['Month']).std())
print("DayofMonth std = ",(data['DayofMonth']).std())
print("DayofWeek std = ",(data['DayOfWeek']).std())
print("DepTime std = ",(data['DepTime']).std())
print("CRSDepTime std = ",(data['CRSDepTime']).std())
print("ArrTime std = ",(data['ArrTime']).std())
print("CRSArrTime std = ",(data['CRSArrTime']).std())
print("FlightNum std = ",(data['FlightNum']).std())
print("ActualElapsedTime std = ",(data['ActualElapsedTime']).std())
print("CRSElapsedTime std = ",(data['CRSElapsedTime']).std())
print("AirTime std = ",(data['AirTime']).std())
print("ArrDelay std = ",(data['ArrDelay']).std())
print("DepDelay std = ",(data['DepDelay']).std())
print("Distance std = ",(data['Distance']).std())
print("TaxiIn std = ",(data['TaxiIn']).std())
print("TaxiOut std = ",(data['TaxiOut']).std())
print("Cancelled std = ",(data['Cancelled']).std())
print("Diverted std = ",(data['Diverted']).std())
print("CarrierDelay std = ",(data['CarrierDelay']).std())
print("WeatherDelay std = ",(data['WeatherDelay']).std())
print("NASDelay std = ",(data['NASDelay']).std())
print("SecurityDelay std = ",(data['SecurityDelay']).std())
print("LateAircraftDelay std = ",(data['LateAircraftDelay']).std())
# Out:
# Year std =  0.0
# Month std =  3.4067459449928776
# DayofMonth std =  8.816907553677147
# DayofWeek std =  1.9878671907640242
# DepTime std =  479.6043726240319
# CRSDepTime std =  465.31193576927336
# ArrTime std =  507.2959112226317
# CRSArrTime std =  484.29022696582615
# FlightNum std =  1958.2018111288355
# ActualElapsedTime std =  69.76675476491299
# CRSElapsedTime std =  68.95110962540681
# AirTime std =  66.93448415758803
# ArrDelay std =  39.18367332331145
# DepDelay std =  35.999364345569205
# Distance std =  558.291925236074
# TaxiIn std =  4.841739580072486
# TaxiOut std =  11.356381252265075
# Cancelled std =  0.14175385527813536
# Diverted std =  0.04697227879154009
# CarrierDelay std =  39.866551834416214
# WeatherDelay std =  23.87014548623755
# NASDelay std =  31.646401056059744
# SecurityDelay std =  1.4302343972215519
# LateAircraftDelay std =  39.82741362093459

# %%
cov_Year  = (data['Year'].std()/data['Year'].mean())*100
cov_Month  = (data['Month'].std()/data['Month'].mean())*100
cov_DayofMonth  = (data['DayofMonth'].std()/data['DayofMonth'].mean())*100
cov_DayOfWeek  = (data['DayOfWeek'].std()/data['DayOfWeek'].mean())*100
cov_DepTime  = (data['DepTime'].std()/data['DepTime'].mean())*100
cov_CRSDepTime  = (data['CRSDepTime'].std()/data['CRSDepTime'].mean())*100
cov_ArrTime  = (data['ArrTime'].std()/data['ArrTime'].mean())*100
cov_CRSArrTime  = (data['CRSArrTime'].std()/data['CRSArrTime'].mean())*100
cov_FlightNum  = (data['FlightNum'].std()/data['FlightNum'].mean())*100
cov_ActualElapsed  = (data['ActualElapsedTime'].std()/data['ActualElapsedTime'].mean())*100
cov_CRSElapsedTime  = (data['CRSElapsedTime'].std()/data['CRSElapsedTime'].mean())*100
cov_AirTime  = (data['AirTime'].std()/data['AirTime'].mean())*100
cov_ArrDelay  = (data['ArrDelay'].std()/data['ArrDelay'].mean())*100
cov_DepDelay  = (data['DepDelay'].std()/data['DepDelay'].mean())*100
cov_Distance  = (data['Distance'].std()/data['Distance'].mean())*100
cov_TaxiIn  = (data['TaxiIn'].std()/data['TaxiIn'].mean())*100
cov_TaxiOut  = (data['TaxiOut'].std()/data['TaxiOut'].mean())*100
cov_Cancelled  = (data['Cancelled'].std()/data['Cancelled'].mean())*100
cov_Diverted  = (data['Diverted'].std()/data['Diverted'].mean())*100
cov_CarrierDelay  = (data['CarrierDelay'].std()/data['CarrierDelay'].mean())*100
cov_WeatherDelay  = (data['WeatherDelay'].std()/data['WeatherDelay'].mean())*100
cov_NasDelay  = (data['NASDelay'].std()/data['NASDelay'].mean())*100
cov_SecurityDelay  = (data['SecurityDelay'].std()/data['SecurityDelay'].mean())*100
cov_LateAircraftDelay  = (data['LateAircraftDelay'].std()/data['LateAircraftDelay'].mean())*100

# %%
print(" Year Cov = " ,cov_Year , " %")
print(" Month Cov = " ,cov_Month , " %")
print(" DayofMonth Cov = " ,cov_DayofMonth , " %")
print(" DayOfWeek Cov = " ,cov_DayOfWeek , " %")
print(" DepTime Cov = " ,cov_DepTime , " %")
print(" CRSDeptTime Cov = " ,cov_CRSDepTime , " %")
print(" ArrTime Cov = " ,cov_ArrTime , " %")
print(" CRSArrTime Cov = " ,cov_CRSArrTime, " %")
print(" FlightNum Cov = " ,cov_FlightNum, " %")
print(" ActualElapsed Cov = " ,cov_ActualElapsed, " %")
print(" CRSElapsedTime Cov = " ,cov_CRSElapsedTime, " %")
print(" AirTime Cov = " ,cov_AirTime, " %")
print(" ArrDelay Cov = " ,cov_ArrDelay, " %")
print(" DeepDelay Cov = " ,cov_DepDelay, " %")
print(" Distance Cov = " ,cov_Distance, " %")
print(" TaxiIn Cov = " ,cov_TaxiIn, " %")
print(" TaxiOut Cov = " ,cov_TaxiOut, " %")
print(" Cancelled Cov = " ,cov_Cancelled, " %")
print(" Diverted Cov = " ,cov_Diverted, " %")
print(" CarrierDelay Cov = " ,cov_CarrierDelay, " %")
print(" WeatherDelay Cov = " ,cov_WeatherDelay, " %")
print(" NasDelay Cov = " ,cov_NasDelay, " %")
print(" SecurityDelay Cov = " ,cov_SecurityDelay , " %")
print(" LateAircraftDelay Cov = " ,cov_LateAircraftDelay, " %")
# Out:
#  Year Cov =  0.0  %
#  Month Cov =  53.509562233117045  %
#  DayofMonth Cov =  56.05058019356949  %
#  DayOfWeek Cov =  50.71649399947407  %
#  DepTime Cov =  35.86855946865681  %
#  CRSDeptTime Cov =  34.97338831850851  %
#  ArrTime Cov =  34.2174739685913  %
#  CRSArrTime Cov =  32.35649692666016  %
#  FlightNum Cov =  88.22942082730994  %
#  ActualElapsed Cov =  54.893187472336045  %
#  CRSElapsedTime Cov =  53.60360600284429  %
#  AirTime Cov =  64.48201574282719  %
#  ArrDelay Cov =  468.85165608454156  %
#  DeepDelay Cov =  354.3278445808184  %
#  Distance Cov =  77.04587971100483  %
#  TaxiIn Cov =  70.82694663125383  %
#  TaxiOut Cov =  68.96835859654917  %
#  Cancelled Cov =  690.985969372474  %
#  Diverted Cov =  2124.2379704334153  %
#  CarrierDelay Cov =  254.77244334164774  %
#  WeatherDelay Cov =  669.1909273259023  %
#  NasDelay Cov =  184.14274545470198  %
#  SecurityDelay Cov =  2586.2700105970785  %
#  LateAircraftDelay Cov =  189.4158688661373  %
